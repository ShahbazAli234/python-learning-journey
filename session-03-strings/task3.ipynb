# %% [markdown]
# <a href="https://colab.research.google.com/github/ShahbazAli234/python-learning-journey/blob/main/session-03-strings/task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##  Python Learning Journey — Session 3
#
# **Topics Covered:** Strings in Python — String Manipulation, Slicing, Symmetry Check, Word Reversal, Common/Uncommon Words, Duplicate Removal
#
# **About:** This notebook contains my practice solutions for Session 3 exercises, covering Python strings. Each problem includes the question, my solution, and sample output.
#
# ---

# %% [markdown]
# ### **Problem 01:** Create Short Form from initial character
# Given a string create short form of the string from Initial character. Short form should be capitalised.
#
# Example:
#
# `Input:`
# ```
# Data science mentorship program
# ```
#
# `Output:`
# ```
# DSMP
# ```

# %%
# Code here

s = input('Enter the string ')
words = s.split()
result = ''

for word in words:
    result = result + word[0].upper()

print('The short form of string is',result)
# Out:
# Enter the string dilbar
# The short form of string is D

# %% [markdown]
# ###`Problem 02`: Append second string in the middle of first string
#
# `Input:`
# ```
# campusx
# data
# ```
# `Output`:
#
# ```
# camdatapusx
# ```

# %%
# Code here

s1 = input('Enter first string: ')
s2 = input('Enter second string: ')

middle_index = len(s1) // 2

left_part = s1[:middle_index]
right_part = s1[middle_index:]
result = left_part + s2 + right_part
# result = s1[:middle_index] + s2 + s1[middle_index:]

print(result)
# Out:
# Enter first string: Parwish
# Enter second string: Munawar
# ParMunawarwish

# %% [markdown]
# ### ``Problem 03``:Given string contains a combination of the lower and upper case letters. Write a program to arrange the characters of a string so that all lowercase letters should come first.
#
# Given:
#
# `str1 = PyNaTive`
#
# Expected Output:
#
# `yaivePNT`

# %%
# Code here

s = input('Enter the string: ')

lower = ''
upper = ''

for i in s:
    if i.islower():
        lower = lower + i
    else:
        upper = upper + i

result = lower + upper
print(result)
# Out:
# Enter the string: PyNaTi98ve
# yaivePNT98

# %% [markdown]
# ### `Problem 04:`Take a alphanumeric string input and print the sum and average of the digits that appear in the string, ignoring all other characters.
#
# Input:
#
# `hel123O4every093`
#
# Output:
#
# ```
# Sum: 22
# Avg: 2.75
# ```

# %%
# Code here

s = input('Enter alphanumeric string: ')

total = 0
counter = 0

for i in s:
    if i.isdigit():
        total = total + int(i)
        counter += 1

avrg = total/counter

print('Sum:',total)
print('Average:',avrg)
# Out:
# Enter alphanumeric string: hel123O4every093
# Sum: 22
# Average: 3.142857142857143

# %% [markdown]
# ### `Problem 05:` Removal of all characters from a string except integers
# `Given:`
#
# ```
# str1 = 'I am 25 years and 10 months old'
# ```
# `Expected Output:`
# ```
# 2510
# ```

# %%
# Code here

s = input('Enter a string: ')

for i in s:
    if i.isdigit():
      print(i,end = '')
# Out:
# Enter a string: I am 25 years and 10 months old
# 2510

# %%
# Code here

s = input('Enter alphanumeric string: ')

result = ""

for i in s:
    if i.isdigit():
        result = result + i

print(result)
# Both codes are completely correct

# %% [markdown]
# ### `Problem 06`: Check whether the string is Symmetrical.
#
# **Statement:** Given a string. the task is to check if the string is symmetrical or not. A string is said to be symmetrical if both the halves of the string are the same.
#
# **Example 1:**
#
# `Input`
#
# ```bash
# khokho
# ```
#
# `Output`
#
# ```bash
# The entered string is symmetrical
# ```

# %%
# Code here

s = input('Enter a String: ')

middle_part = len(s) // 2

left_part = s[:middle_part]
right_part = s[middle_part:]

if left_part == right_part:
    print('The entered string is symmetrical')
else:
    print('The entered string is not symmetrical')
# Out:
# Enter a String: symmsym
# The entered string is not symmetrical

# %% [markdown]
# ### `Problem 07`: Reverse words in a given String
#
# **Statement:** We are given a string and we need to reverse words of a given string.
#
# **Example 1:**
#
# `Input:`
#
# ```bash
# geeks quiz practice code
# ```
#
# `Output:`
#
# ```bash
# code practice quiz geeks
# ```
#
# **Example 2:**
#
# `Input:`
#
# ```bash
# my name is laxmi
# ```
#
# `Output:`
#
# ```bash
# laxmi is name my
# ```

# %%
# Code here

s = input('Enter a string: ')

words = s.split()

reverse = words[::-1]
print(' '.join(reverse))

# CODE 2

s = input('Enter a string: ')
print(' '.join(s.split()[::-1]))
# Out:
# Enter a string: my name is shahbaz
# shahbaz is name my
# Enter a string: code practice quiz geeks
# geeks quiz practice code

# %% [markdown]
# ### `Problem 08`: Find uncommon words from two Strings.
#
# **Statement:** Given two sentences as strings **A** and **B**. The task is to return a list of all uncommon words. A word is uncommon if it appears exactly once in any one of the sentences, and does not appear in the other sentence. Note: A sentence is a string of space-separated words. Each word consists only of lowercase letters.
#
# **Example 1:**
#
# `Input:`
#
# ```bash
# A = "apple banana mango"
# B = "banana fruits mango"
# ```
#
# `Output:`
#
# ```bash
# ['apple', 'fruits']
# ```

# %%
# Code here

A = input('A = ')
B = input('B = ')

words_A = A.split()
words_B = B.split()

result = []

for word in words_A:
    if word not in words_B:
        result = result + [word]

for word in words_B:
    if word not in words_A:
      result = result + [word]

print(result)

# Limitation in this code
# Question says 'A word is uncommon if it appears exactly once in any one of the sentences, and does not appear in the other sentence'
# if word repeats in a sentence, program also prints that word.
# Out:
# A = apple banana apple mango
# B = banana orange mango orange
# ['apple', 'apple', 'orange', 'orange']

# %%
A = input('A = ')
B = input('B = ')

words_A = A.split()
words_B = B.split()

result = []

for word in words_A:
    if word not in words_B and words_A.count(word) == 1:
        result.append(word)

for word in words_B:
    if word not in words_A and words_B.count(word) == 1:
        result.append(word)

print(result)
# Out:
# A = apple banana mango apple
# B = banana orange fruits orange
# ['mango', 'fruits']

# %%
# Without using list and displaying result in string format

A = input('A = ')
B = input('B = ')

words_A = A.split()
words_B = B.split()

result = ""

for word in words_A:
    if word not in words_B and words_A.count(word) == 1:
        result = result + word + " "

for word in words_B:
    if word not in words_A and words_B.count(word) == 1:
        result = result + word + " "

print(result.strip())

# %% [markdown]
# ### `Problem 09`: Word location in String.
#
# **Statement:** Find a location of a word in a given sentence.
#
# **Example 1:**
#
# `Input:`
#
# ```bash
# Sentence: We can learn data science through campusx mentorship program.
#
# word: campusx
# ```
#
# `Output:`
#
# ```bash
# Location of the word is 7.
# ```
#
# Note- Don't use index/find functions

# %%
# Code here

s = input('Sentence: ')

words = s.split()

target = input('Enter word: ')

position = 1
for word in words:
    if word == target:
        print('Location of the word is',position)
        break

    position += 1

else:
    print('Word not found')
# Out:
# Sentence: We can learn data science through campusx mentorship program.
# Enter word: campusx
# Location of the word is 7

# %%
# Code here


s = input('Enter a sentence: ')
word = input('Enter word whose location to find: ')

words = s.split()

count = 0

for i in words:
    count += 1
    if i == word:
        print('location of word is',count)
        break

else:
    print('word not found')

# both codes are correct but this is more better
# Out:
# Enter a sentence: We can learn data science through campusx mentorship program.can
# Enter word whose location to find: can
# location of word is 2

# %% [markdown]
# ### `Problem 10`: Write a program that can remove all the duplicate characters from a string. User will provide the input.

# %%
# Code here

s = input('Enter a string: ')
result = ''

for i in s:
    if i not in result:
        result = result + i

print(result)
# Out:
# Enter a string: programming
# progamin
