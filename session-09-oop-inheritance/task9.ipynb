# %% [markdown]
# <a href="https://colab.research.google.com/github/ShahbazAli234/python-learning-journey/blob/main/session-09-oop-inheritance/task9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Python Learning Journey — Session 9
#
# **Topics Covered:** OOP — Inheritance, Method Overriding, Has-A Relationship (Composition), Abstract Classes, Dunder Method Overriding
#
# **About:** This notebook contains my practice solutions for Session 9 exercises, covering inheritance, composition, and abstraction in Python OOP. Each problem includes the question, my solution, and sample output.
#
# ---

# %% [markdown]
# ### `Problem-1:` Class inheritence
#
# Create a **Bus** child class that inherits from the Vehicle class. The default fare charge of any vehicle is seating capacity * 100. If Vehicle is Bus instance, we need to add an extra 10% on full fare as a maintenance charge. So total fare for bus instance will become the final amount = total fare + 10% of the total fare.
#
# Note: The bus seating capacity is 50. so the final fare amount should be 5500. You need to override the fare() method of a Vehicle class in Bus class.

# %%
# Write code here(10/10)

class Vehicle:

    def __init__(self, seating_capacity):
        self.seating_capacity = seating_capacity

    def fare(self):
        return self.seating_capacity * 100


class Bus(Vehicle):

    def __init__(self,seating_capacity):
        super().__init__(seating_capacity)

    def fare(self):
        total = super().fare()
        return total + 0.1 * total


v = Vehicle(50)
v.fare()

b = Bus(50)
b.fare()
# Out:
# 5500.0

# %% [markdown]
# ### `Problem-2:` Class Inheritence
#
# Create a Bus class that inherits from the Vehicle class. Give the capacity argument of *Bus.seating_capacity()* a default value of 50.
#
# Use the following code for your parent Vehicle class.

# %%
class Vehicle:

    def __init__(self, seating_capacity):
        self.seating_capacity = seating_capacity

class Bus(Vehicle):

    def __init__(self,seating_capacity = 50):
        super().__init__(seating_capacity)

b = Bus(70)
b.seating_capacity
# Out:
# 70

# %% [markdown]
# ### `Problem-3:` Write a program that has a class Point. Define another class Location which has two objects (Location & Destination) of class Point. Also define a function in Location that prints the reflection of Destination on the x axis.
#
# (Has-A relationship) problem

# %%
class Point:

    def __init__(self, x, y):
        self.x = x
        self.y = y

class Location:

    def __init__(self, location, destination):
        self.location = location
        self.destination = destination

    def reflection(self):
        return self.destination.x, -(self.destination.y)

# %%
p1 = Point(3,5)
p2 = Point(7,9)

l = Location(p1, p2)
print(l.reflection())
# Out:
# (7, -9)

# %% [markdown]
# ### `Problem-4:` Write a program that has an abstract class Polygon. Derive two classes Rectangle and Triamgle from Polygon and write methods to get the details of their dimensions and hence calculate the area.

# %%
from abc import ABC, abstractmethod

class Polygon(ABC):

    @abstractmethod
    def get_dimensions(self, *args):
        pass

    @abstractmethod
    def calculate_area(self):
        pass


class  Rectangle(Polygon):

    def get_dimensions(self,length,width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width

class Triangle(Polygon):

    def get_dimensions(self, base, height):
        self.base = base
        self.height = height

    def calculate_area(self):
        return 0.5 * self.base * self.height


r = Rectangle()
r.get_dimensions(3,4)
print(r.calculate_area())

t = Triangle()
t.get_dimensions(4,9)
print(t.calculate_area())

#  p = Polygon() --> gives error because we can not create an object of abstract class
# Out:
# 12
# 18.0

# %%
from abc import ABC, abstractmethod

class Polygon(ABC):

    @abstractmethod
    def get_dimensions(self):
        pass

    @abstractmethod
    def calculate_area(self):
        pass


class  Rectangle(Polygon):

    def get_dimensions(self):
        self.length = int(input("Enter length: "))
        self.width = int(input("Enter width: "))

    def calculate_area(self):
        return self.length * self.width

class Triangle(Polygon):

    def get_dimensions(self):
        self.base = int(input('Enter base: '))
        self.height = int(input("Enter height: "))

    def calculate_area(self):
        return 0.5 * self.base * self.height


r = Rectangle()
r.get_dimensions()
print('Area of Rectangle:',r.calculate_area())

t = Triangle()
t.get_dimensions()
print('Area of Triangle:',t.calculate_area())
# Out:
# Enter length: 12
# Enter width: 8
# Area of Rectangle: 96
# Enter base: 24
# Enter height: 16
# Area of Triangle: 192.0

# %% [markdown]
# ### `Problem-5:` Write a program with class Bill. The users have the option to pay the bill either by cheque or by cash. Use the inheritance to model this situation.

# %%
from abc import ABC,abstractmethod

class Bill(ABC):

    def __init__(self,bill_amount):
        self.bill_amount = bill_amount

    @abstractmethod
    def pay_bill(self):
        pass

class Cash(Bill):

    def pay_bill(self):
        print("Bill paid by cash")
        print('Amount =',self.bill_amount)

class Cheque(Bill):

    def __init__(self,cheque_number,bank_name,bill_amount):
        self.cheque_number = cheque_number
        self.bank_name = bank_name
        super().__init__(bill_amount)

    def pay_bill(self):
        print('Bill paid by cheque')
        print('Cheque no:',self.cheque_number)
        print('Bank Name:',self.bank_name)
        print('Amount =',self.bill_amount)

# %%
c1 = Cash(5000)
c2 = Cheque(1234,'UBL',4000)
c1.pay_bill()
c2.pay_bill()
# Out:
# Bill paid by cash
# Amount = 5000
# Bill paid by cheque
# Cheque no: 1234
# Bank Name: UBL
# Amount = 4000

# %% [markdown]
# ###`Q-6:` FlexibleDict
# As of now we are accessing values from dictionary with exact keys. Now we want to amend accessing values functionality. if a dict have key `1` (int) the even if we try to access values by giving `'1'` (1 as str) as key, we should get the same result and vice versa.
#
# Write a class `FlexibleDict` upon builtin `dict` class with above required functionality.
#
# Hint- `dict[key] => dict.__getitem__(key)`

# %% [markdown]
# Ex.
# ```
# fd = FlexibleDict()
# fd['a'] = 100
# print(fd['a']) # Like regular dict
#
# fd[5] = 500
# print(fd[5]) # Like regular dict
#
# fd[1] = 100
# print(fd['1']) # actual Key is int but still trying to access through str key.
# fd['1'] = 100
# print(fd[1])
#
# ```
# `Output:`
# ```
# 100
# 500
# 100
# 100
#
# ```

# %%
class FlexibleDict(dict):

    def __setitem__(self, key, value):

        if isinstance(key, str) and key.isdigit():
            key = int(key)

        super().__setitem__(key, value)


    def __getitem__(self, key):

        if isinstance(key, str) and key.isdigit():
            key = int(key)

        return super().__getitem__(key)

# %%
fd = FlexibleDict()

fd['a'] = 100
print(fd['a'])

fd[5] = 500
print(fd[5]) # Like regular dict

fd[1] = 100
print(fd['1']) # actual Key is int but still trying to access through str key.
fd['1'] = 100
print(fd[1])
# Out:
# 100
# 500
# 100
# 100
